# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import opendatasets as od
import os

# %%
os.listdir()
# Out:
# ['.idea',
#  '.ipynb_checkpoints',
#  '.jovianrc',
#  'changes-visitors-covid.csv',
#  'first_django_project',
#  'Untitled.ipynb',
#  'Visualization']

# %%
link1 = 'https://docs.google.com/spreadsheets/d/1YNKhCn7E1u2IyWkF2GKLoOijWjWC7d0JnwXJ-MBLbRc/edit?usp=sharing'
link2 = f"https://docs.google.com/spreadsheets/d/1ZWRwkWDhc_YYEGdiysMPGk1lzqfe4r2oZGgjKKA6Q8o/edit?usp=sharing"
#link2 = owid-covid-data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17264/3062440556.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#       3
#       4 link1 = 'https://docs.google.com/spreadsheets/d/1YNKhCn7E1u2IyWkF2GKLoOijWjWC7d0JnwXJ-MBLbRc/edit?usp=sharing'
#       5 link2 = f"https://docs.google.com/spreadsheets/d/1ZWRwkWDhc_YYEGdiysMPGk1lzqfe4r2oZGgjKKA6Q8o/edit?usp=sharing"
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
df1 = pd.read_csv('changes-visitors-covid.csv')

# %%
df1
# Out:
#             Entity Code         Day  retail_and_recreation  \
# 0      Afghanistan  AFG  2020-02-17                  0.000
# 1      Afghanistan  AFG  2020-02-18                  0.750
# 2      Afghanistan  AFG  2020-02-19                  0.400
# 3      Afghanistan  AFG  2020-02-20                  0.000
# 4      Afghanistan  AFG  2020-02-21                  0.000
# ...            ...  ...         ...                    ...
# 61945     Zimbabwe  ZWE  2021-05-28                 32.286
# 61946     Zimbabwe  ZWE  2021-05-29                 33.143
# 61947     Zimbabwe  ZWE  2021-05-30                 34.714
# 61948     Zimbabwe  ZWE  2021-05-31                 35.143
# 61949     Zimbabwe  ZWE  2021-06-01                 38.429
#
#        grocery_and_pharmacy  residential  transit_stations   parks  workplaces
# 0                     4.000        1.333             5.667   1.000      -6.333
# 1                     4.250        0.750             6.500   1.500      -3.250
# ...

# %%
os.listdir()
# Out:
# ['.idea',
#  '.ipynb_checkpoints',
#  '.jovianrc',
#  'changes-visitors-covid.csv',
#  'first_django_project',
#  'owid-covid-data (1).csv',
#  'sklearn-decision-trees-random-forests-Copy1.ipynb',
#  'Untitled.ipynb',
#  'Visualization']

# %%
df2 = pd.read_csv('owid-covid-data (1).csv')

# %%
df2
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 93326      ZWE    Africa     Zimbabwe  2021-05-30      38944.0       11.0
# 93327      ZWE    Africa     Zimbabwe  2021-05-31      38961.0       17.0
# 93328      ZWE    Africa     Zimbabwe  2021-06-01      38998.0       37.0
# 93329      ZWE    Africa     Zimbabwe  2021-06-02      39031.0       33.0
# 93330      ZWE    Africa     Zimbabwe  2021-06-03      39092.0       61.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df1
# Out:
#             Entity Code         Day  retail_and_recreation  \
# 0      Afghanistan  AFG  2020-02-17                  0.000
# 1      Afghanistan  AFG  2020-02-18                  0.750
# 2      Afghanistan  AFG  2020-02-19                  0.400
# 3      Afghanistan  AFG  2020-02-20                  0.000
# 4      Afghanistan  AFG  2020-02-21                  0.000
# ...            ...  ...         ...                    ...
# 61945     Zimbabwe  ZWE  2021-05-28                 32.286
# 61946     Zimbabwe  ZWE  2021-05-29                 33.143
# 61947     Zimbabwe  ZWE  2021-05-30                 34.714
# 61948     Zimbabwe  ZWE  2021-05-31                 35.143
# 61949     Zimbabwe  ZWE  2021-06-01                 38.429
#
#        grocery_and_pharmacy  residential  transit_stations   parks  workplaces
# 0                     4.000        1.333             5.667   1.000      -6.333
# 1                     4.250        0.750             6.500   1.500      -3.250
# ...

# %%
required_df1 = df1.loc[df1['Entity'] == "India"]

# %%
required_df1
# Out:
#       Entity Code         Day  retail_and_recreation  grocery_and_pharmacy  \
# 23897  India  IND  2020-02-17                  0.667                 1.667
# 23898  India  IND  2020-02-18                  0.500                 1.750
# 23899  India  IND  2020-02-19                  0.400                 1.800
# 23900  India  IND  2020-02-20                  0.500                 2.000
# 23901  India  IND  2020-02-21                 -0.143                 1.714
# ...      ...  ...         ...                    ...                   ...
# 24363  India  IND  2021-05-28                -61.714               -25.000
# 24364  India  IND  2021-05-29                -61.286               -24.429
# 24365  India  IND  2021-05-30                -61.143               -24.714
# 24366  India  IND  2021-05-31                -60.143               -23.429
# 24367  India  IND  2021-06-01                -58.714               -21.143
#
#        residential  transit_stations   parks  workplaces
# ...

# %%
df2
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 93326      ZWE    Africa     Zimbabwe  2021-05-30      38944.0       11.0
# 93327      ZWE    Africa     Zimbabwe  2021-05-31      38961.0       17.0
# 93328      ZWE    Africa     Zimbabwe  2021-06-01      38998.0       37.0
# 93329      ZWE    Africa     Zimbabwe  2021-06-02      39031.0       33.0
# 93330      ZWE    Africa     Zimbabwe  2021-06-03      39092.0       61.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
required_df2 = df2.loc[df2['iso_code'] == "IND"]
required_df2
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 38584      IND      Asia    India  2020-01-30          1.0        1.0
# 38585      IND      Asia    India  2020-01-31          1.0        0.0
# 38586      IND      Asia    India  2020-02-01          1.0        0.0
# 38587      IND      Asia    India  2020-02-02          2.0        1.0
# 38588      IND      Asia    India  2020-02-03          3.0        1.0
# ...        ...       ...      ...         ...          ...        ...
# 39070      IND      Asia    India  2021-05-30   28047534.0   152734.0
# 39071      IND      Asia    India  2021-05-31   28175044.0   127510.0
# 39072      IND      Asia    India  2021-06-01   28307832.0   132788.0
# 39073      IND      Asia    India  2021-06-02   28441986.0   134154.0
# 39074      IND      Asia    India  2021-06-03   28574350.0   132364.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
required_df1
# Out:
#       Entity Code         Day  retail_and_recreation  grocery_and_pharmacy  \
# 23897  India  IND  2020-02-17                  0.667                 1.667
# 23898  India  IND  2020-02-18                  0.500                 1.750
# 23899  India  IND  2020-02-19                  0.400                 1.800
# 23900  India  IND  2020-02-20                  0.500                 2.000
# 23901  India  IND  2020-02-21                 -0.143                 1.714
# ...      ...  ...         ...                    ...                   ...
# 24363  India  IND  2021-05-28                -61.714               -25.000
# 24364  India  IND  2021-05-29                -61.286               -24.429
# 24365  India  IND  2021-05-30                -61.143               -24.714
# 24366  India  IND  2021-05-31                -60.143               -23.429
# 24367  India  IND  2021-06-01                -58.714               -21.143
#
#        residential  transit_stations   parks  workplaces
# ...

# %%
required_df1['date'] = required_df1['Day']
required_df1
# Out:
# C:\Users\Shivank\AppData\Local\Temp/ipykernel_17264/3577549376.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   required_df1['date'] = required_df1['Day']
#       Entity Code         Day  retail_and_recreation  grocery_and_pharmacy  \
# 23897  India  IND  2020-02-17                  0.667                 1.667
# 23898  India  IND  2020-02-18                  0.500                 1.750
# 23899  India  IND  2020-02-19                  0.400                 1.800
# 23900  India  IND  2020-02-20                  0.500                 2.000
# 23901  India  IND  2020-02-21                 -0.143                 1.714
# ...      ...  ...         ...                    ...                   ...
# ...

# %%
new_df = required_df2[['date','new_cases']]
new_df
# Out:
#              date  new_cases
# 38584  2020-01-30        1.0
# 38585  2020-01-31        0.0
# 38586  2020-02-01        0.0
# 38587  2020-02-02        1.0
# 38588  2020-02-03        1.0
# ...           ...        ...
# 39070  2021-05-30   152734.0
# 39071  2021-05-31   127510.0
# 39072  2021-06-01   132788.0
# 39073  2021-06-02   134154.0
# 39074  2021-06-03   132364.0
#
# [491 rows x 2 columns]

# %%
new_df
# Out:
#              date  new_cases
# 38584  2020-01-30        1.0
# 38585  2020-01-31        0.0
# 38586  2020-02-01        0.0
# 38587  2020-02-02        1.0
# 38588  2020-02-03        1.0
# ...           ...        ...
# 39070  2021-05-30   152734.0
# 39071  2021-05-31   127510.0
# 39072  2021-06-01   132788.0
# 39073  2021-06-02   134154.0
# 39074  2021-06-03   132364.0
#
# [491 rows x 2 columns]

# %%
new_df.loc[38602]
# Out:
# date         2020-02-17
# new_cases           0.0
# Name: 38602, dtype: object

# %%
new_df.loc[39072]
# Out:
# date         2021-06-01
# new_cases      132788.0
# Name: 39072, dtype: object

# %%
new_df = new_df.loc[38602:39072]
new_df
# Out:
#              date  new_cases
# 38602  2020-02-17        0.0
# 38603  2020-02-18        0.0
# 38604  2020-02-19        0.0
# 38605  2020-02-20        0.0
# 38606  2020-02-21        0.0
# ...           ...        ...
# 39068  2021-05-28   173790.0
# 39069  2021-05-29   165553.0
# 39070  2021-05-30   152734.0
# 39071  2021-05-31   127510.0
# 39072  2021-06-01   132788.0
#
# [471 rows x 2 columns]

# %%
merged_df = new_df.merge(required_df1,on = "date")
merged_df
# Out:
#            date  new_cases Entity Code         Day  retail_and_recreation  \
# 0    2020-02-17        0.0  India  IND  2020-02-17                  0.667
# 1    2020-02-18        0.0  India  IND  2020-02-18                  0.500
# 2    2020-02-19        0.0  India  IND  2020-02-19                  0.400
# 3    2020-02-20        0.0  India  IND  2020-02-20                  0.500
# 4    2020-02-21        0.0  India  IND  2020-02-21                 -0.143
# ..          ...        ...    ...  ...         ...                    ...
# 466  2021-05-28   173790.0  India  IND  2021-05-28                -61.714
# 467  2021-05-29   165553.0  India  IND  2021-05-29                -61.286
# 468  2021-05-30   152734.0  India  IND  2021-05-30                -61.143
# 469  2021-05-31   127510.0  India  IND  2021-05-31                -60.143
# 470  2021-06-01   132788.0  India  IND  2021-06-01                -58.714
#
#      grocery_and_pharmacy  residential  transit_stations   parks  workplaces
# ...

# %%
target_column = ['new_cases']
train_column = list(merged_df.columns)[5:]
train_column
# Out:
# ['retail_and_recreation',
#  'grocery_and_pharmacy',
#  'residential',
#  'transit_stations',
#  'parks',
#  'workplaces']

# %%
train_df = merged_df[train_column]
train_df
# Out:
#      retail_and_recreation  grocery_and_pharmacy  residential  \
# 0                    0.667                 1.667        0.000
# 1                    0.500                 1.750        0.000
# 2                    0.400                 1.800        0.200
# 3                    0.500                 2.000        0.000
# 4                   -0.143                 1.714        0.714
# ..                     ...                   ...          ...
# 466                -61.714               -25.000       24.143
# 467                -61.286               -24.429       23.714
# 468                -61.143               -24.714       23.714
# 469                -60.143               -23.429       23.286
# 470                -58.714               -21.143       22.714
#
#      transit_stations   parks  workplaces
# 0               2.000   3.000       3.000
# 1               2.000   3.250       3.000
# 2               1.800   2.800       3.200
# 3               2.333   3.167       3.333
# ...

# %%
target_df =  new_df['new_cases']
target_df
# Out:
# 38602         0.0
# 38603         0.0
# 38604         0.0
# 38605         0.0
# 38606         0.0
#            ...
# 39068    173790.0
# 39069    165553.0
# 39070    152734.0
# 39071    127510.0
# 39072    132788.0
# Name: new_cases, Length: 471, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeClassifier(random_state=42)

# %%
model.fit(train_df,target_df)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
train_preds = model.predict(train_df)

# %%
train_preds
# Out:
# array([0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 2.00000e+00,
#        0.00000e+00, 2.30000e+01, 2.00000e+00, 1.00000e+00, 3.00000e+00,
#        5.00000e+00, 4.00000e+00, 1.30000e+01, 6.00000e+00, 1.10000e+01,
#        9.00000e+00, 2.00000e+01, 1.10000e+01, 6.00000e+00, 2.30000e+01,
#        1.40000e+01, 3.80000e+01, 5.00000e+01, 8.60000e+01, 6.60000e+01,
#        1.03000e+02, 3.70000e+01, 1.21000e+02, 7.00000e+01, 1.60000e+02,
#        1.00000e+02, 3.70000e+01, 2.27000e+02, 1.46000e+02, 6.01000e+02,
#        5.45000e+02, 2.40000e+01, 5.15000e+02, 5.06000e+02, 1.19000e+03,
#        5.33000e+02, 6.05000e+02, 8.09000e+02, 8.73000e+02, 8.48000e+02,
#        7.59000e+02, 1.24800e+03, 1.03400e+03, 8.35000e+02, 1.10800e+03,
#        9.22000e+02, 1.37000e+03, 1.89300e+03, 9.24000e+02, 1.54100e+03,
# ...

# %%
accuracy_score(target_df,train_preds)
# Out:
# 1.0

# %%
from sklearn.tree import plot_tree, export_text

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(80,20))
plot_tree(model, feature_names=train_df.columns, max_depth=2, filled=True);
